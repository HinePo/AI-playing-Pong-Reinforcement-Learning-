# %% [markdown]
# <a href="https://colab.research.google.com/github/HinePo/AI-playing-Pong-Reinforcement-Learning-/blob/main/Reinforcement_Learning_Pong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Github notebo
#
# https://github.com/GrupoTuring/Workshop-de-Aprendizado-por-Reforco/blob/master/Pong%20-%20Gabarito.ipynb

# %% [markdown]
# # 🎮 Workshop de Introdução ao Aprendizado por Reforço
# ⠀
#
# Bem vindes ao **Workshop de Introdução ao Aprendizado por Reforço**, organizado pelo Grupo Turing!
#
# O objetivo deste evento é ensinar o básico necessário da área de Aprendizado por Reforço utilizando um dos maiores clássicos da história dos video-games: ***Pong***.
#
# ![Pong](https://media2.giphy.com/media/aTGwuEFyg6d8c/giphy.gif)

# %%
# Instala os ambientes do Grupo Turing
# !pip install -U turing-envs
# Out:
# Collecting turing-envs
#   Downloading https://files.pythonhosted.org/packages/7c/4a/9e8561071b58293026896d942cc4f1abf0224eaf68484b11264c51eccb5b/turing_envs-0.1.1-py3-none-any.whl
# Collecting pygame
#   Downloading https://files.pythonhosted.org/packages/8e/24/ede6428359f913ed9cd1643dd5533aefeb5a2699cc95bea089de50ead586/pygame-1.9.6-cp36-cp36m-manylinux1_x86_64.whl (11.4MB)
#      |████████████████████████████████| 11.4MB 275kB/s
# Requirement already satisfied, skipping upgrade: gym in /usr/local/lib/python3.6/dist-packages (from turing-envs) (0.17.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym->turing-envs) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from gym->turing-envs) (1.4.1)
# Requirement already satisfied, skipping upgrade: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->turing-envs) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym->turing-envs) (1.5.0)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->turing-envs) (0.16.0)
# Installing collected packages: pygame, turing-envs
# Successfully installed pygame-1.9.6 turing-envs-0.1.1

# %% [markdown]
# ## 🏓 Sobre o Pong
#
# Começaremos falando sobre o problema, ou seja, sobre o jogo Pong. Este que foi o primeiro jogo de video-game lucrativo da história, publicado em 1972, constando 48 anos de legado.
#
# Pong simula uma partida de tênis, existem duas "raquetes" e uma bola, e o objetivo de cada uma das raquetes é não somente evitar que a bola passe por ela, como também fazer com que esta passe pela linha que a outra raquete protege, criando assim a premissa que sustenta o interesse pelo jogo. Queremos então desenvolver um algoritmo capaz de &mdash; sem nenhuma explicação adicional &mdash; maximizar as suas recompensas, sendo as ações, os estados e as recompensas, todas relativas ao jogo Pong. Teremos no final, portanto, um modelo treinado capaz de bom desempenho dentro do ambiente.

# %% [markdown]
# ## 💻 Programando...

# %% [markdown]
# ### Importando o Gym
#
# O **[Gym](https://gym.openai.com/)** é uma biblioteca desenvolvida pela OpenAI que contém várias implementações prontas de ambientes de Aprendizagem por Reforço. Ela é muito utilizada quando se quer testar um algoritmo de agente sem ter o trabalho de programar seu próprio ambiente.
#
# <img src="https://user-images.githubusercontent.com/10624937/42135602-b0335606-7d12-11e8-8689-dd1cf9fa11a9.gif" alt="Exemplos de Ambientes do Gym" class="inline"/>
# <figcaption>Exemplo de Ambientes do Gym</figcaption>
# <br>
#
# Para se ter acesso a esses ambientes, basta importar o Gym da seguinte forma:

# %%
import gym

# %% [markdown]
# ### O que é um Ambiente?
#
# Um **Ambiente** de Aprendizagem por Reforço é um espaço que representa o nosso problema, é o objeto com o qual o nosso agente deve interagir para cumprir sua função. Isso significa que o agente toma **ações** nesse ambiente, e recebe **recompensas** dele com base na qualidade de sua tomada de decisões.
#
# Todos os ambientes são dotados de um **espaço de observações**, que é a forma pela qual o agente recebe informações e deve se basear para a tomada de decisões, e um **espaço de ações**, que especifica as ações possíveis do agente. No xadrez, por exemplo, o espaço de observações seria o conjunto de todas as configurações diferentes do tabuleiro, e o espaço de ações seria o conjunto de todos os movimentos permitidos.
#
# <img src="https://www.raspberrypi.org/wp-content/uploads/2016/08/giphy-1-1.gif" alt="Uma Ação do Xadrez" class="inline"/>
#
# ### Como Funciona um Ambiente do Gym?
#
# Agora que você já sabe o que é um ambiente, é preciso entender como nosso agente interage efetivamente com ele. Todos os ambientes do Gym possuem alguns métodos simples para facilitar a comunicação com eles:
#
# <br>
#
# | Método         | Funcionalidade                                        |
# | :------------- |:----------------------------------------------------- |
# | `reset()`      | Inicializa o ambiente e recebe a observação inicial   |
# | `step(action)` | Executa uma ação e recebe a observação e a recompensa |
# | `render()`     | Renderiza o ambiente                                  |
# | `close()`      | Fecha o ambiente                                      |
#
# <br>
#
# Assim, o código para interagir com o ambiente costuma seguir o seguinte modelo:
#
# ---
#
# ```python
# env = gym.make("Nome do Ambiente")                 # Cria o ambiente
# state = ambiente.reset()                           # Inicializa o ambiente
# done = False                                       # Variável que diz se acabou
#
# while not done:
#     env.render()                                   # Renderiza o ambiente
#     acao = random()                                # Define alguma ação
#     state, reward, done, info = env.step(acao)     # Executa uma ação
#
# env.close()                                        # Fecha o ambiente
# ```
#
# ---
#
# No Google Colab, a renderização precisa ser feita de uma forma um pouco diferente:
#
# ---
#
# ```python
# env = gym.make("Nome do Ambiente")              # Cria o ambiente
# inicia_renderizacao()                           # Inicia a renderização do episódio
# state = env.reset()                             # Inicializa o ambiente
# done = False
#
# while not done:
#     salva_frame(env)                            # Salva o frame atual
#     state, reward, done, info = env.step(acao)  # Executa uma ação
#
# env.close()                                     # Fecha o ambiente
# termina_renderização()                          # Renderiza todos os frames do episódio
# ```
#
# ---
#
# A célula abaixo define as funções `inicia_renderizacao` `salva_frame` e `termina_renderizacao` necessárias para a renderização no colab. Não é necessário entender o código dessa célula.

# %%
# Código para renderizar o ambiente no Colab
# Não precisa se preocupar em entender o código!

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import display_html
from tqdm.notebook import tqdm

_frames = []

def salva_frame(env):
    _frames.append({
        'img': env.render(mode='rgb_array', wait=False),
        'pts': env.score[:],
    })
    
def inicia_renderizacao():
    _frames.clear()

def termina_renderizacao():
    h, w, _ = _frames[0]['img'].shape
    plt.figure(dpi=72, figsize=(w/72, h/72))
    plt.axis('off')

    patch = plt.imshow(_frames[0]['img'][::3, ::3])
    title = plt.text(0.5, 0.95, '', transform=plt.gca().transAxes,
                     ha='center', va='top', c='white', size=18)
    plt.tight_layout()

    def renderiza_frame(f):
        patch.set_data(f['img'])
        title.set_text(f'{f["pts"][0]} x {f["pts"][1]}')
    
    skip = 3
    anim = FuncAnimation(fig=plt.gcf(),
                         func=renderiza_frame,
                         frames=tqdm(_frames[::skip], desc='Renderizando'),
                         interval=skip*1000/env.fps)
    
    display_html(anim.to_jshtml(), raw=True)
    plt.clf()

# %% [markdown]
# ### Criando um Ambiente
#
# Para utilizar um dos ambientes do Gym, nós usamos a função ```gym.make()```, passando o nome do ambiente desejado como parâmetro e guardando o valor retornado em uma variável que chamaramos de ```env```. A lista com todos os ambientes do gym pode ser encontrada [aqui](https://gym.openai.com/envs/#classic_control). Nesse workshop, utilizaremos um ambiente de pong do Grupo Turing, que requer a instalação do [Turing Envs](https://github.com/GrupoTuring/turing-envs).

# %%
env = gym.make("turing_envs:pong-easy-v0")
env.seed(0) # para ter sempre o mesmo resultado
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# [0]

# %% [markdown]
# Nesse caso, nós vamos utilizar o ambiente ```turing_envs:pong-easy-v0```, um ambiente que reproduz o jogo _Pong_.
#
# <img src="data:image/png;base64,..." width="400px" alt="Ambiente do turing_envs:pong-easy-v0" class="inline"/>
#
# #### Características do Pong
#
# Antes de treinar qualquer agente, primeiro é preciso entender melhor quais as características do nosso ambiente.
#
# O **Espaço de Observação** do pong (modo fácil) é definido por 2 informações:
#
# | Estado    | Informação                            |
# | :-------- | :------------------------------------ |
# | 0         | Distância _x_ entre a bola e o agente |
# | 1         | Distância _y_ entre a bola e o agente |
#
# Dessa forma, a cada instante recebemos uma lista da observação com o seguinte formato:

# %%
print(env.observation_space.sample()) # sample: pega amostra/observação aleatória do espaço de observação
# Out:
# [-388.43253  123.90438]

# %% [markdown]
# Já o **Espaço de Ação** é composto por três ações: mover o jogador para cima, baixo, ou deixá-lo parado:
#
# | Ação | Significado      |
# | :--- | :--------------- |
# | 0    | Ficar parado     |
# | 1    | Mover para baixo |
# | 2    | Mover para cima  |
#
# Por exemplo, para mover a barra para a cima, fazemos `env.step(2)`.

# %%
print(env.action_space.sample()) # sample: pega ação aleatória do espaço de ação
# Out:
# 0

# %% [markdown]
# Por fim, cada vez que tomamos uma ação, recebemos do ambiente uma **recompensa**, conforme a tabela abaixo:
#
# | Ocorrência          | Recompensa |
# | :------------------ | ---------: |
# | Ponto do Agente     | $+500$     |
# | Ponto do Oponente   | $-500$     |
# | Vitória do Agente   | $+2000$    |
# | Vitória do Oponente | $-2000$    |
#
# O primeiro jogador a fazer quatro pontos ganha o jogo. Além disso, as recompensas são cumulativas. Isso significa que se o oponente fizer um ponto _e_ ganhar o jogo, a recompensa é de $-2500$.

# %% [markdown]
# ### ✍ Exercício de Gym
#
# Agora que você já entende como o Gym funciona, vamos tentar aplicar esse conhecimento criando uma função que roda um episódio de Pong tomando ações aleatórias!
#
# OBS: Lembrete das funções do Gym
#
# | Método                 | Funcionalidade                                          |
# | :--------------------- |:------------------------------------------------------- |
# | `reset()`              | Inicializa o ambiente e recebe a observação inicial     |
# | `step(action)`         | Executa uma ação e recebe a observação e a recompensa   |
# | `render()`             | Renderiza o ambiente                                    |
# | `close()`              | Fecha o ambiente                                        |

# %%
# Essa função deve rodar um episodio de Pong escolhendo ações aleatórias
def rodar_ambiente():
    # Criando o ambiente 'turing_envs:pong-easy-v0'
    env = gym.make("turing_envs:pong-easy-v0")
    inicia_renderizacao()

    # Resete o ambiente e receba o primeiro estado
    state = env.reset()

    # Inicializando done como false
    done = False

    # Loop de treino
    while not done:
        # Escolha uma acao aleatoria
        action = env.action_space.sample()

        # Tome essa acao e receba as informacoes do estado seguinte
        next_state, reward, done, info = env.step(action)

        # Renderize o ambiente
        salva_frame(env)

        # Atualizando o estado
        state = next_state

    # Fechando o ambiente
    env.close()
    termina_renderizacao()

# %%
# Testando a função
rodar_ambiente()
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# HBox(children=(FloatProgress(value=0.0, description='Renderizando', max=371.0, style=ProgressStyle(description…
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc2049a22c09946fdb0d01e60ea3b90ce">
#   <div class="anim-controls">
#     <input id="_anim_sliderc2049a22c09946fdb0d01e60ea3b90ce" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc2049a22c09946fdb0d01e60ea3b90ce.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animc2049a22c09946fdb0d01e60ea3b90ce.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectc2049a22c09946fdb0d01e60ea3b90ce" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c2049a22c09946fdb0d01e60ea3b90ce"
#              >
#       <label for="_anim_radio1_c2049a22c09946fdb0d01e60ea3b90ce">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c2049a22c09946fdb0d01e60ea3b90ce"
#              checked>
#       <label for="_anim_radio2_c2049a22c09946fdb0d01e60ea3b90ce">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c2049a22c09946fdb0d01e60ea3b90ce"
#              >
#       <label for="_anim_radio3_c2049a22c09946fdb0d01e60ea3b90ce">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc2049a22c09946fdb0d01e60ea3b90ce";
#     var slider_id = "_anim_sliderc2049a22c09946fdb0d01e60ea3b90ce";
#     var loop_select_id = "_anim_loop_selectc2049a22c09946fdb0d01e60ea3b90ce";
#     var frames = new Array(371);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAJ3UlEQVR4nO3dX2jW5f/H8ff+mPaHToqZhoFklDip\
# dA3CA086EwYGdRKLwsbqJOooPAmspYlQOxUpojoppHS1o5IOAvujpAt20EkLM13/zBNba2337+CL\
# 4+c3v/55uU2dj8fh57qv63PdMHjyue57W1Oj0WgUAFyk5su9AQCuTgICQERAAIgICAARAQEgIiAA\
# RAQEgIiAABAREAAiAgJAREAAiLReyuSJiYk6evToTO0FgDm0bNmyam3NM3BJATl+/Hh1dnZeyhIA\
# XCZDQ0O1dOnSeL4jLAAiAgJAREAAiAgIABEBASAiIABEBASAiIAAEBEQACICAkBEQACICAgAEQFh\
# Xmlqaqre3t7av39//fjjj3X48OHasmVL3XDDDXO6jzVr1tTu3btrZGSkvv/++3rvvfeqvb19TvcA\
# s01AmFf6+vqqr6+vvvvuu9q8e

# %% [markdown]
# ## 👩‍💻 Algoritmo

# %% [markdown]
# Primeiramente, precisaremos utilizar uma biblioteca chamada ***NumPy*** para auxiliar nas computações. Esta é uma biblioteca do Python capaz de manusear diversas computações matemáticas com maestria e será importante futuramente para o nosso trabalho.

# %%
import numpy as np # Importando a biblioteca NumPy
import gym         # Importando a Biblioteca Gym

# Criando o nosso Ambiente: Pong
env = gym.make("turing_envs:pong-easy-v0")

# Número total de ações: 3
# 0 = parado; 1 = baixo; 2 = cima
n_acoes = env.action_space.n

print('Número de ações:', n_acoes)
# Out:
# Número de ações: 3
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ### 🔢 Discretizando o nosso Estado
#
# Como comentamos anteriormente, o estado que o nosso agente recebe consiste das distâncias horizontal e vertical da raquete controlada até a bola. Dessa forma, se a nossa tela possuir 800 unidades de largura e 600 unidades de altura, a quantidade total de diferentes estados possíveis seria aproximadamente $3 \times 800 \times 600 = 960000$.
#
# Como Q-Learning é um algoritmo que guarda em uma tabela as estimativas do Q de cada ação para cada estado, esse gigantesco número de estados exigiria não somente guardar como atualizar cada um desses Q. Não é uma situação ideal.
#
# Para simplificar (e agilizar) a situação, "discretizar" os nossos estados é razoável e esperado. Faremos com que estados similares o suficiente sejam considerados como iguais e comparilhem das mesmas estimativas, já que não faz sentido distinguir o estado (502,234) do estado (515,222).

# %%
def discretiza_estado(estado):
    return tuple(round(x/10) for x in estado)

# %% [markdown]
# ### 🔀 Escolhendo Ações
#
# Para o processo de de escolha de ação, é necessário lembrar do dilema entre **Exploração** e **Explotação**. Nosso modelo precisa estabelecer um equilíbrio entre **explorar o ambiente**, escolhendo ações que ele não costuma tomar para encontrar alguma solução que ele não havia pensado antes, e **aproveitar** o conhecimento que já possui, tomando ações que ele acredita serem as melhores para maximizar as recompensas que receberá no episódio.
#
# De forma a assegurar que o agente busque tanto novas alternativas que podem gerar melhores resultados quanto seja capaz de utilizar o aprendizado obtido de forma a maximizar seu retorno, existem diversas estratégias para a escolha de exploração e explotação. Uma das mais utilizadas, que também vamos utilizar aqui, é a seleção de ações pela estratégia do **"$\epsilon$-greedy"**.
#
# #### A Estratégia **$\epsilon$-greedy**
#
# O algoritmo "$\epsilon$-greedy" é definido da seguinte forma: é retirado um número aleatório, no intervalo entre 0 e 1. caso este número tenha valor inferior ao valor do epsilon, a escolha será de uma ação aleatória, o que configura exploração. Caso este número seja superior ao epsilon, a ação a ser tomada é a que gera a maior recompensa de acordo com os valores da tabela Q.
#
# Este valor de $\epsilon$ não é constante ao longo do treinamento. Inicialmente, este valor é alto, incentivando a maior exploração do ambiente. A medida que o treinamento ocorre, mais informação sobre o ambiente é adquirida, conseguindo uma tabela Q mais representativa da realidade. Dessa forma, quanto mais avançado no treinamento, menor a necessidade de exploração e maior a necessidade de exploitar o conhecimento adquirido para maximizar a recompensa. Esta atualização do $\epsilon$ é chamada **"$\epsilon$-decay"** (decaimento do epsilon). Também é estabelecido um valor mínimo para o $\epsilon$, para que o agente nunca pare completamente de explorar o ambiente.

# %%
# Constantes da Política Epsilon Greedy
# Epsilon: probabilidade de experimentar uma ação aleatória
EPSILON = 0.7        # Valor inicial do epsilon
EPSILON_MIN = 0.01   # Valor mínimo de epsilon
DECAIMENTO = 0.98    # Fator de decaímento do epsilon (por episódio)

# %%
def escolhe_acao(env, Q, estado, epsilon):
    # Se não conhecermos ainda o estado, inicializamos o Q de cada ação como 0
    if estado not in Q.keys(): Q[estado] = [0] * n_acoes

    # Escolhemos um número aleatório com "np.random.random()"
    # Se esse número for menor que epsilon, tomamos uma ação aleatória
    if np.random.random() < epsilon:
        # Escolhemos uma ação aleatória, com env.action_space.sample()
        acao = env.action_space.sample()
    else:
        # Escolhemos a melhor ação para o estado atual, com np.argmax()
        acao = np.argmax(Q[estado])
    return acao

# %% [markdown]
# Para rodar uma partida, são necessárias algumas etapas. Inicialmente, o ambiente é reiniciado, de forma a inicar um novo episódio. Em seguida, é necessário discretizar o estado, pelos motivos já explicados acima. Esta discretização deve ocorrer toda vez em que estamos em um novo estado.
#
# Enquanto o ambiente não chega em seu estado terminal, indicado pela variável "done", será feito o processo de escolha de ações e, uma vez escolhida, deve-se receber do ambiente o próximo estado, a recompensa que a ação escolhida gerou, além do sinal se estamos no estado terminal. Todo o processo é repetido novamente para o próximo estado, até o final do episódio.
#
# Como explicado na seção sobre a biblioteca "Gym", "env.render()" tem como papel mostrar o ambiente (neste caso, a partida de Pong)

# %%
def roda_partida(env, Q, renderiza=True):
    if renderiza:
        inicia_renderizacao()
        
    # Resetamos o ambiente
    estado = env.reset()

    # Discretizamos o estado
    estado = discretiza_estado(estado)
    
    done = False
    retorno = 0
    
    while not done:
        # Escolhemos uma ação
        acao = escolhe_acao(env, Q, estado, epsilon=0)

        # Tomamos nossa ação escolhida e recebemos informações do próximo estado
        prox_estado, recompensa, done, info = env.step(acao)

        # Discretizamos o próximo estado
        prox_estado = discretiza_estado(prox_estado)

        # Renderizamos o ambiente
        if renderiza:
            salva_frame(env)

        retorno += recompensa
        estado = prox_estado

    print(f'retorno {retorno:.1f},  '
          f'placar {env.score[0]}x{env.score[1]}')
    
    env.close()
    
    if renderiza:
        termina_renderizacao()

# %%
# Rodamos uma partida de Pong
Q = {}
roda_partida(env, Q)
# Out:
# retorno -4000.0,  placar 0x4
# HBox(children=(FloatProgress(value=0.0, description='Renderizando', max=368.0, style=ProgressStyle(description…
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9ddae573ba9342a9a37d487d22700ed7">
#   <div class="anim-controls">
#     <input id="_anim_slider9ddae573ba9342a9a37d487d22700ed7" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9ddae573ba9342a9a37d487d22700ed7.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim9ddae573ba9342a9a37d487d22700ed7.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select9ddae573ba9342a9a37d487d22700ed7" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9ddae573ba9342a9a37d487d22700ed7"
#              >
#       <label for="_anim_radio1_9ddae573ba9342a9a37d487d22700ed7">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9ddae573ba9342a9a37d487d22700ed7"
#              checked>
#       <label for="_anim_radio2_9ddae573ba9342a9a37d487d22700ed7">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9ddae573ba9342a9a37d487d22700ed7"
#              >
#       <label for="_anim_radio3_9ddae573ba9342a9a37d487d22700ed7">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9ddae573ba9342a9a37d487d22700ed7";
#     var slider_id = "_anim_slider9ddae573ba9342a9a37d487d22700ed7";
#     var loop_select_id = "_anim_loop_select9ddae573ba9342a9a37d487d22700ed7";
#     var frames = new Array(368);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAJuElEQVR4nO3dS4iWZR/H8f8cTDvQpnDSmECyg6hU\
# M9NAtHDRUhgwqEUxUdgwtYl24SZQJk2CcitSiwoikNKp2UhSEFikpBPMok0TZh466CZLm2aed9Hr\
# 8PpWo/3moI6fz/K+n+u6rxtmni/39cyhqdFoNAoA/qXmS70AAK5MAgJAREAAiAgIABEBASAiIABE\
# BASAiIAAEBEQACICAkBEQACItE5n8NjYWB05cmSm1gLAHGpvb6/W1jwD0wrIsWPHqru7ezpTAHCJ\
# DA8P19KlS+PxtrAAiAgIABEBASAiIABEBASAiIAAEBEQACICAkBEQACICAgAEQEBICIgAEQEhHml\
# qamp+vv7a9++ffXdd9/VoUOHauPGjXXdddfN6To6Ojpq586dNTo6Wt988029++67tWrVqjldA8w2\
# AWFeGRgYqIGBgfr6669rw4YNN

# %% [markdown]
# ## 🏋️‍♀️ Treinamento
#
# Agora sim chegaremos no treinamento propriamente dito. Usando os conceitos vistos na apresentação e nas seções anteriores do notebook, podemos definir a função de treinamento que vai permitir que o agente aprenda a jogar PONG por meio de Q-Learning tabular.

# %% [markdown]
# O algoritmo se baseia na atualização de estimativas dos valores Q para cada par estado-ação, de forma a chegar a uma tabela cada vez mais próxima da realidade do ambiente. Dessa forma, devemos atualizar cada entrada da tabela de acordo com a **equação do Q-Learning**:
#
# $$Q*(s,a) \leftarrow Q*(s,a) + \alpha \cdot \left[r + \gamma \cdot \max_{a'} (Q(s',a')) - Q(s, a)\right]$$
#
# Esta equação corrige o valor do Q(s,a) de acordo com os valores anteriores somados a uma parecela de correção, de forma a minimizar o erro. A recompensa é representada por r, enquanto os outros parâmetros estão explicados a seguir:

# %% [markdown]
# * "ALFA" ($\alpha$): algoritmos de aprendizado de máquina costumam precisar de uma forma de serem otimizados. Q-learning trabalha em cima de gradientes, uma entidade matemática que indica a direção para maximizar (ou minimizar) uma função. Dispondo dessa direção, precisamos informar qual deve ser o tamanho do passo a ser dado antes de atualizar a nova "direção ideal".
#
# * "GAMA" ($\gamma$): denota o quanto desejamos que nosso algoritmo considere eventos futuros. Se "$\gamma = 1$", nosso algoritmo avaliará que a situação futura ser melhor que a atual é tão importante quanto a recompensa da situação atual em si, por outro lado, se "$\gamma = 0$", os eventos futuros não apresentam importância alguma para nosso algoritmo.
#
# * "Q" é um dicionário, ou seja, uma estrtura de dados capaz de buscar elementos de forma rápida. Nós o usaremos para guardar valores relativos às estimativas do algoritmo.

# %%
# Hiperparâmetros do Q-Learning
ALFA = 0.05          # Learning rate
GAMA = 0.9           # Fator de desconto

# Dicionário dos valores de Q
# Chaves: estados; valores: qualidade Q atribuida a cada ação
Q = {}

# %%
def atualiza_q(Q, estado, acao, recompensa, prox_estado):
    # para cada estado ainda não descoberto, iniciamos seu valor como nulo
    if estado not in Q.keys(): Q[estado] = [0] * n_acoes
    if prox_estado not in Q.keys(): Q[prox_estado] = [0] * n_acoes

    # equação do Q-Learning
    Q[estado][acao] = Q[estado][acao] + ALFA*(recompensa + GAMA*np.max(Q[prox_estado]) - Q[estado][acao])

# %% [markdown]
# Pickle é uma maneira de salvar dados em um arquivo independente. Dessa forma, podemos gravar os valores da nossa tabela Q em um arquivo próprio, ficando disponível para ser acessada em outro momento. Assim, podemos efetivamente salvar o modelo treinado para ser utilizado posteriormente. Abaixo, já estão presentes as funções de salvar e de abrir as tabelas com pickle.

# %%
import pickle

def salva_tabela(Q, nome = 'model.pickle'):
    with open(nome, 'wb') as pickle_out:
        pickle.dump(Q, pickle_out)

def carrega_tabela(nome = 'model.pickle'):
    with open(nome, 'rb') as pickle_out:
        return pickle.load(pickle_out)

# %% [markdown]
# A função de treinamento tem estrutura semelhante à função roda_partida, conforme visto anteriormente. A cada episódio, o embiente deve ser reiniciado e discretizado, e deve indicar que o episódio ainda não chegou em sua condição terminal. Devemos também zerar o valor da recompensa, pois não devemos utilizar o retorno do episódio anterior.
#
# Enquanto o episódio não chega no final, o agente deve escolher uma ação e tomar a ação escolhida. Uma vez tomada a ação, o ambiente fornece o próximo estado, a recompensa recebida com a escolha, a indicação se o estado é terminal e informações sobre o ambiente.
#
# Em seguida, devemos discretizar o próximo estado e atualizar os valores de q, o retorno e o estado atual.
#
# Por fim, devemos atualizar o valor do epsilon, de acordo com o método $\epsilon$-greedy, onde deve ocorrer o decaimento do epsilon, mas seu valor nunca deve ser inferior ao valor mínimo definido.

# %% [markdown]
# * `N_EPISODIOS` dita quantas vezes o agente deverá "reviver" o ambiente (vitórias e derrotas) antes de acabar seu treinamento.

# %%
N_EPISODIOS = 250    # quantidade de episódios que treinaremos

# %%
def treina(env, Q):
    retornos = []      # retorno de cada episódio
    epsilon = EPSILON

    for episodio in range(1, N_EPISODIOS+1):
        # resetar o ambiente
        estado = env.reset()

        # discretizar o estado inicial
        estado = discretiza_estado(estado)
        
        done = False
        retorno = 0
        
        while not done:
            # escolher uma ação
            acao = escolhe_acao(env, Q, estado, epsilon)

            # tomar a ação
            prox_estado, recompensa, done, info = env.step(acao)

            # discretizar o próximo estado
            prox_estado = discretiza_estado(prox_estado)

            atualiza_q(Q, estado, acao, recompensa, prox_estado)

            retorno += recompensa
            estado = prox_estado

        # calcular o próximo epsilon
        epsilon = max(DECAIMENTO*epsilon, EPSILON_MIN) # max  garante que Epsilon nunca será inferior ao Epsilon mínimo
        epsilon = max(epsilon, EPSILON_MIN)

        retornos.append(retorno)

        if episodio % 10 == 0:
            salva_tabela(Q)

        print(f'episódio {episodio},  '
              f'retorno {retorno:7.1f},  '
              f'retorno médio (últimos 10 episódios) {np.mean(retornos[-10:]):7.1f},  '
              f'placar {env.score[0]}x{env.score[1]},  '
              f'epsilon: {epsilon:.3f}')
        
    env.close()

# %%
treina(env, Q)
# Out:
# episódio 1,  retorno -4000.0,  retorno médio (últimos 10 episódios) -4000.0,  placar 0x4,  epsilon: 0.686
# episódio 2,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3750.0,  placar 1x4,  epsilon: 0.672
# episódio 3,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3666.7,  placar 1x4,  epsilon: 0.659
# episódio 4,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3750.0,  placar 0x4,  epsilon: 0.646
# episódio 5,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3700.0,  placar 1x4,  epsilon: 0.633
# episódio 6,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3750.0,  placar 0x4,  epsilon: 0.620
# episódio 7,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3785.7,  placar 0x4,  epsilon: 0.608
# episódio 8,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3812.5,  placar 0x4,  epsilon: 0.596
# episódio 9,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3833.3,  placar 0x4,  epsilon: 0.584
# episódio 10,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3800.0,  placar 1x4,  epsilon: 0.572
# episódio 11,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3800.0,  placar 0x4,  epsilon: 0.561
# episódio 12,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3800.0,  placar 1x4,  epsilon: 0.549
# episódio 13,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3800.0,  placar 1x4,  epsilon: 0.538
# episódio 14,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3800.0,  placar 0x4,  epsilon: 0.528
# episódio 15,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3850.0,  placar 0x4,  epsilon: 0.517
# episódio 16,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3850.0,  placar 0x4,  epsilon: 0.507
# episódio 17,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3850.0,  placar 0x4,  epsilon: 0.497
# episódio 18,  retorno  2500.0,  retorno médio (últimos 10 episódios) -3200.0,  placar 4x3,  epsilon: 0.487
# episódio 19,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3150.0,  placar 1x4,  epsilon: 0.477
# episódio 20,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3200.0,  placar 0x4,  epsilon: 0.467
# episódio 21,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3200.0,  placar 0x4,  epsilon: 0.458
# episódio 22,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3200.0,  placar 1x4,  epsilon: 0.449
# episódio 23,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3250.0,  placar 0x4,  epsilon: 0.440
# episódio 24,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3200.0,  placar 1x4,  epsilon: 0.431
# episódio 25,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3150.0,  placar 1x4,  epsilon: 0.422
# episódio 26,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3050.0,  placar 2x4,  epsilon: 0.414
# episódio 27,  retorno -3000.0,  retorno médio (últimos 10 episódios) -2950.0,  placar 2x4,  epsilon: 0.406
# episódio 28,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3500.0,  placar 2x4,  epsilon: 0.398
# episódio 29,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3450.0,  placar 2x4,  epsilon: 0.390
# episódio 30,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 1x4,  epsilon: 0.382
# episódio 31,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 0x4,  epsilon: 0.374
# episódio 32,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3450.0,  placar 0x4,  epsilon: 0.367
# episódio 33,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 1x4,  epsilon: 0.359
# episódio 34,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3450.0,  placar 0x4,  epsilon: 0.352
# episódio 35,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 2x4,  epsilon: 0.345
# episódio 36,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3500.0,  placar 0x4,  epsilon: 0.338
# episódio 37,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3600.0,  placar 0x4,  epsilon: 0.331
# episódio 38,  retorno -2500.0,  retorno médio (últimos 10 episódios) -3550.0,  placar 3x4,  epsilon: 0.325
# episódio 39,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3550.0,  placar 2x4,  epsilon: 0.318
# episódio 40,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3550.0,  placar 1x4,  epsilon: 0.312
# episódio 41,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3500.0,  placar 1x4,  epsilon: 0.306
# episódio 42,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3500.0,  placar 0x4,  epsilon: 0.300
# episódio 43,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3550.0,  placar 0x4,  epsilon: 0.294
# episódio 44,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3450.0,  placar 2x4,  epsilon: 0.288
# episódio 45,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3550.0,  placar 0x4,  epsilon: 0.282
# episódio 46,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3550.0,  placar 0x4,  epsilon: 0.276
# episódio 47,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3500.0,  placar 1x4,  epsilon: 0.271
# episódio 48,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3600.0,  placar 1x4,  epsilon: 0.265
# episódio 49,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3700.0,  placar 0x4,  epsilon: 0.260
# episódio 50,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3750.0,  placar 0x4,  epsilon: 0.255
# episódio 51,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3800.0,  placar 0x4,  epsilon: 0.250
# episódio 52,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3750.0,  placar 1x4,  epsilon: 0.245
# episódio 53,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3650.0,  placar 2x4,  epsilon: 0.240
# episódio 54,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3700.0,  placar 1x4,  epsilon: 0.235
# episódio 55,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3650.0,  placar 1x4,  epsilon: 0.230
# episódio 56,  retorno  2500.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 4x3,  epsilon: 0.226
# episódio 57,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 1x4,  epsilon: 0.221
# episódio 58,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3050.0,  placar 0x4,  epsilon: 0.217
# episódio 59,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 1x4,  epsilon: 0.213
# episódio 60,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 0x4,  epsilon: 0.208
# episódio 61,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 0x4,  epsilon: 0.204
# episódio 62,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 1x4,  epsilon: 0.200
# episódio 63,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3100.0,  placar 0x4,  epsilon: 0.196
# episódio 64,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3150.0,  placar 0x4,  epsilon: 0.192
# episódio 65,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3100.0,  placar 2x4,  epsilon: 0.188
# episódio 66,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3750.0,  placar 0x4,  epsilon: 0.185
# episódio 67,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3700.0,  placar 2x4,  epsilon: 0.181
# episódio 68,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3650.0,  placar 1x4,  epsilon: 0.177
# episódio 69,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3700.0,  placar 0x4,  epsilon: 0.174
# episódio 70,  retorno  3000.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 4x2,  epsilon: 0.170
# episódio 71,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3000.0,  placar 0x4,  epsilon: 0.167
# episódio 72,  retorno -3000.0,  retorno médio (últimos 10 episódios) -2950.0,  placar 2x4,  epsilon: 0.163
# episódio 73,  retorno -2500.0,  retorno médio (últimos 10 episódios) -2800.0,  placar 3x4,  epsilon: 0.160
# episódio 74,  retorno -2500.0,  retorno médio (últimos 10 episódios) -2650.0,  placar 3x4,  epsilon: 0.157
# episódio 75,  retorno -3000.0,  retorno médio (últimos 10 episódios) -2650.0,  placar 2x4,  epsilon: 0.154
# episódio 76,  retorno -3000.0,  retorno médio (últimos 10 episódios) -2550.0,  placar 2x4,  epsilon: 0.151
# episódio 77,  retorno -3500.0,  retorno médio (últimos 10 episódios) -2600.0,  placar 1x4,  epsilon: 0.148
# episódio 78,  retorno -4000.0,  retorno médio (últimos 10 episódios) -2650.0,  placar 0x4,  epsilon: 0.145
# episódio 79,  retorno -4000.0,  retorno médio (últimos 10 episódios) -2650.0,  placar 0x4,  epsilon: 0.142
# episódio 80,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3350.0,  placar 0x4,  epsilon: 0.139
# episódio 81,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3350.0,  placar 0x4,  epsilon: 0.136
# episódio 82,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3450.0,  placar 0x4,  epsilon: 0.134
# episódio 83,  retorno -2500.0,  retorno médio (últimos 10 episódios) -3450.0,  placar 3x4,  epsilon: 0.131
# episódio 84,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3550.0,  placar 1x4,  epsilon: 0.128
# episódio 85,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3650.0,  placar 0x4,  epsilon: 0.126
# episódio 86,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3700.0,  placar 1x4,  epsilon: 0.123
# episódio 87,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3650.0,  placar 2x4,  epsilon: 0.121
# episódio 88,  retorno -2500.0,  retorno médio (últimos 10 episódios) -3500.0,  placar 3x4,  epsilon: 0.118
# episódio 89,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3500.0,  placar 0x4,  epsilon: 0.116
# episódio 90,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 2x4,  epsilon: 0.114
# episódio 91,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 0x4,  epsilon: 0.111
# episódio 92,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 0x4,  epsilon: 0.109
# episódio 93,  retorno -2500.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 3x4,  epsilon: 0.107
# episódio 94,  retorno -3000.0,  retorno médio (últimos 10 episódios) -3350.0,  placar 2x4,  epsilon: 0.105
# episódio 95,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3350.0,  placar 0x4,  epsilon: 0.103
# episódio 96,  retorno -4000.0,  retorno médio (últimos 10 episódios) -3400.0,  placar 0x4,  epsilon: 0.101
# episódio 97,  retorno -2500.0,  retorno médio (últimos 10 episódios) -3350.0,  placar 3x4,  epsilon: 0.099
# episódio 98,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3450.0,  placar 1x4,  epsilon: 0.097
# episódio 99,  retorno -2500.0,  retorno médio (últimos 10 episódios) -3300.0,  placar 3x4,  epsilon: 0.095
# episódio 100,  retorno -3500.0,  retorno médio (últimos 10 episódios) -3350.0,  placar 1x4,  epsilon: 0.093
# episódio 101,  retorno  4000.0,  retorno médio (últimos 10 episódios) -2550.0,  placar 4x0,  epsilon: 0.091
# episódio 102,  retorno -3500.0,  retorno médio (últimos 10 episódios) -2500.0,  placar 1x4,  epsilon: 0.089
# episódio 103,  retorno  3000.0,  retorno médio (últimos 10 episódios) -1950.0,  placar 4x2,  epsilon: 0.087
# episódio 104,  retorno -3500.0,  retorno médio (últimos 10 episódios) -2000.0,  placar 1x4,  epsilon: 0.086
# episódio 105,  retorno -3500.0,  retorno médio (últimos 10 episódios) -1950.0,  placar 1x4,  epsilon: 0.084
# episódio 106,  retorno -3500.0,  retorno médio (últimos 10 episódios) -1900.0,  placar 1x4,  epsilon: 0.082
# episódio 107,  retorno -4000.0,  retorno médio (últimos 10 episódios) -2050.0,  placar 0x4,  epsilon: 0.081
# episódio 108,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1950.0,  placar 3x4,  epsilon: 0.079
# episódio 109,  retorno -4000.0,  retorno médio (últimos 10 episódios) -2100.0,  placar 0x4,  epsilon: 0.077
# episódio 110,  retorno  4000.0,  retorno médio (últimos 10 episódios) -1350.0,  placar 4x0,  epsilon: 0.076
# episódio 111,  retorno  2500.0,  retorno médio (últimos 10 episódios) -1500.0,  placar 4x3,  epsilon: 0.074
# episódio 112,  retorno  3500.0,  retorno médio (últimos 10 episódios)  -800.0,  placar 4x1,  epsilon: 0.073
# episódio 113,  retorno     0.0,  retorno médio (últimos 10 episódios) -1100.0,  placar 0x0,  epsilon: 0.071
# episódio 114,  retorno     0.0,  retorno médio (últimos 10 episódios)  -750.0,  placar 0x0,  epsilon: 0.070
# episódio 115,  retorno -3000.0,  retorno médio (últimos 10 episódios)  -700.0,  placar 2x4,  epsilon: 0.069
# episódio 116,  retorno -3500.0,  retorno médio (últimos 10 episódios)  -700.0,  placar 1x4,  epsilon: 0.067
# episódio 117,  retorno -3500.0,  retorno médio (últimos 10 episódios)  -650.0,  placar 1x4,  epsilon: 0.066
# episódio 118,  retorno -3000.0,  retorno médio (últimos 10 episódios)  -700.0,  placar 2x4,  epsilon: 0.065
# episódio 119,  retorno  2500.0,  retorno médio (últimos 10 episódios)   -50.0,  placar 4x3,  epsilon: 0.063
# episódio 120,  retorno -3000.0,  retorno médio (últimos 10 episódios)  -750.0,  placar 2x4,  epsilon: 0.062
# episódio 121,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1250.0,  placar 3x4,  epsilon: 0.061
# episódio 122,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1850.0,  placar 3x4,  epsilon: 0.060
# episódio 123,  retorno -2500.0,  retorno médio (últimos 10 episódios) -2100.0,  placar 3x4,  epsilon: 0.058
# episódio 124,  retorno  4000.0,  retorno médio (últimos 10 episódios) -1700.0,  placar 4x0,  epsilon: 0.057
# episódio 125,  retorno -3500.0,  retorno médio (últimos 10 episódios) -1750.0,  placar 1x4,  epsilon: 0.056
# episódio 126,  retorno  3500.0,  retorno médio (últimos 10 episódios) -1050.0,  placar 4x1,  epsilon: 0.055
# episódio 127,  retorno -3000.0,  retorno médio (últimos 10 episódios) -1000.0,  placar 2x4,  epsilon: 0.054
# episódio 128,  retorno -3000.0,  retorno médio (últimos 10 episódios) -1000.0,  placar 2x4,  epsilon: 0.053
# episódio 129,  retorno -3500.0,  retorno médio (últimos 10 episódios) -1600.0,  placar 1x4,  epsilon: 0.052
# episódio 130,  retorno  3500.0,  retorno médio (últimos 10 episódios)  -950.0,  placar 4x1,  epsilon: 0.051
# episódio 131,  retorno -3000.0,  retorno médio (últimos 10 episódios) -1000.0,  placar 2x4,  epsilon: 0.050
# episódio 132,  retorno  3000.0,  retorno médio (últimos 10 episódios)  -450.0,  placar 4x2,  epsilon: 0.049
# episódio 133,  retorno  2500.0,  retorno médio (últimos 10 episódios)    50.0,  placar 4x3,  epsilon: 0.048
# episódio 134,  retorno -3500.0,  retorno médio (últimos 10 episódios)  -700.0,  placar 1x4,  epsilon: 0.047
# episódio 135,  retorno -2500.0,  retorno médio (últimos 10 episódios)  -600.0,  placar 3x4,  epsilon: 0.046
# episódio 136,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1200.0,  placar 3x4,  epsilon: 0.045
# episódio 137,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1150.0,  placar 3x4,  epsilon: 0.044
# episódio 138,  retorno  3000.0,  retorno médio (últimos 10 episódios)  -550.0,  placar 4x2,  epsilon: 0.043
# episódio 139,  retorno  3000.0,  retorno médio (últimos 10 episódios)   100.0,  placar 4x2,  epsilon: 0.042
# episódio 140,  retorno -4000.0,  retorno médio (últimos 10 episódios)  -650.0,  placar 0x4,  epsilon: 0.041
# episódio 141,  retorno -2500.0,  retorno médio (últimos 10 episódios)  -600.0,  placar 3x4,  epsilon: 0.041
# episódio 142,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1150.0,  placar 3x4,  epsilon: 0.040
# episódio 143,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1650.0,  placar 3x4,  epsilon: 0.039
# episódio 144,  retorno -4000.0,  retorno médio (últimos 10 episódios) -1700.0,  placar 0x4,  epsilon: 0.038
# episódio 145,  retorno  2500.0,  retorno médio (últimos 10 episódios) -1200.0,  placar 4x3,  epsilon: 0.037
# episódio 146,  retorno -4000.0,  retorno médio (últimos 10 episódios) -1350.0,  placar 0x4,  epsilon: 0.037
# episódio 147,  retorno -3000.0,  retorno médio (últimos 10 episódios) -1400.0,  placar 2x4,  epsilon: 0.036
# episódio 148,  retorno -3000.0,  retorno médio (últimos 10 episódios) -2000.0,  placar 2x4,  epsilon: 0.035
# episódio 149,  retorno  3000.0,  retorno médio (últimos 10 episódios) -2000.0,  placar 4x2,  epsilon: 0.034
# episódio 150,  retorno  2500.0,  retorno médio (últimos 10 episódios) -1350.0,  placar 4x3,  epsilon: 0.034
# episódio 151,  retorno -3000.0,  retorno médio (últimos 10 episódios) -1400.0,  placar 2x4,  epsilon: 0.033
# episódio 152,  retorno  3500.0,  retorno médio (últimos 10 episódios)  -800.0,  placar 4x1,  epsilon: 0.032
# episódio 153,  retorno -3500.0,  retorno médio (últimos 10 episódios)  -900.0,  placar 1x4,  epsilon: 0.032
# episódio 154,  retorno -2500.0,  retorno médio (últimos 10 episódios)  -750.0,  placar 3x4,  epsilon: 0.031
# episódio 155,  retorno   500.0,  retorno médio (últimos 10 episódios)  -950.0,  placar 3x2,  epsilon: 0.031
# episódio 156,  retorno -4000.0,  retorno médio (últimos 10 episódios)  -950.0,  placar 0x4,  epsilon: 0.030
# episódio 157,  retorno  3500.0,  retorno médio (últimos 10 episódios)  -300.0,  placar 4x1,  epsilon: 0.029
# episódio 158,  retorno -4000.0,  retorno médio (últimos 10 episódios)  -400.0,  placar 0x4,  epsilon: 0.029
# episódio 159,  retorno  3500.0,  retorno médio (últimos 10 episódios)  -350.0,  placar 4x1,  epsilon: 0.028
# episódio 160,  retorno  2500.0,  retorno médio (últimos 10 episódios)  -350.0,  placar 4x3,  epsilon: 0.028
# episódio 161,  retorno     0.0,  retorno médio (últimos 10 episódios)   -50.0,  placar 3x3,  epsilon: 0.027
# episódio 162,  retorno  2500.0,  retorno médio (últimos 10 episódios)  -150.0,  placar 4x3,  epsilon: 0.027
# episódio 163,  retorno  3000.0,  retorno médio (últimos 10 episódios)   500.0,  placar 4x2,  epsilon: 0.026
# episódio 164,  retorno -3000.0,  retorno médio (últimos 10 episódios)   450.0,  placar 2x4,  epsilon: 0.025
# episódio 165,  retorno -4000.0,  retorno médio (últimos 10 episódios)     0.0,  placar 0x4,  epsilon: 0.025
# episódio 166,  retorno  2500.0,  retorno médio (últimos 10 episódios)   650.0,  placar 4x3,  epsilon: 0.024
# episódio 167,  retorno -2500.0,  retorno médio (últimos 10 episódios)    50.0,  placar 3x4,  epsilon: 0.024
# episódio 168,  retorno -3000.0,  retorno médio (últimos 10 episódios)   150.0,  placar 2x4,  epsilon: 0.024
# episódio 169,  retorno -3500.0,  retorno médio (últimos 10 episódios)  -550.0,  placar 1x4,  epsilon: 0.023
# episódio 170,  retorno  2500.0,  retorno médio (últimos 10 episódios)  -550.0,  placar 4x3,  epsilon: 0.023
# episódio 171,  retorno  3500.0,  retorno médio (últimos 10 episódios)  -200.0,  placar 4x1,  epsilon: 0.022
# episódio 172,  retorno  3000.0,  retorno médio (últimos 10 episódios)  -150.0,  placar 4x2,  epsilon: 0.022
# episódio 173,  retorno  2500.0,  retorno médio (últimos 10 episódios)  -200.0,  placar 4x3,  epsilon: 0.021
# episódio 174,  retorno  2500.0,  retorno médio (últimos 10 episódios)   350.0,  placar 4x3,  epsilon: 0.021
# episódio 175,  retorno -3000.0,  retorno médio (últimos 10 episódios)   450.0,  placar 2x4,  epsilon: 0.020
# episódio 176,  retorno -3500.0,  retorno médio (últimos 10 episódios)  -150.0,  placar 1x4,  epsilon: 0.020
# episódio 177,  retorno  2500.0,  retorno médio (últimos 10 episódios)   350.0,  placar 4x3,  epsilon: 0.020
# episódio 178,  retorno  4000.0,  retorno médio (últimos 10 episódios)  1050.0,  placar 4x0,  epsilon: 0.019
# episódio 179,  retorno  3000.0,  retorno médio (últimos 10 episódios)  1700.0,  placar 4x2,  epsilon: 0.019
# episódio 180,  retorno  3000.0,  retorno médio (últimos 10 episódios)  1750.0,  placar 4x2,  epsilon: 0.018
# episódio 181,  retorno  3500.0,  retorno médio (últimos 10 episódios)  1750.0,  placar 4x1,  epsilon: 0.018
# episódio 182,  retorno -4000.0,  retorno médio (últimos 10 episódios)  1050.0,  placar 0x4,  epsilon: 0.018
# episódio 183,  retorno -3500.0,  retorno médio (últimos 10 episódios)   450.0,  placar 1x4,  epsilon: 0.017
# episódio 184,  retorno  2500.0,  retorno médio (últimos 10 episódios)   450.0,  placar 4x3,  epsilon: 0.017
# episódio 185,  retorno -3500.0,  retorno médio (últimos 10 episódios)   400.0,  placar 1x4,  epsilon: 0.017
# episódio 186,  retorno   500.0,  retorno médio (últimos 10 episódios)   800.0,  placar 3x2,  epsilon: 0.016
# episódio 187,  retorno -2500.0,  retorno médio (últimos 10 episódios)   300.0,  placar 3x4,  epsilon: 0.016
# episódio 188,  retorno  2500.0,  retorno médio (últimos 10 episódios)   150.0,  placar 4x3,  epsilon: 0.016
# episódio 189,  retorno  3000.0,  retorno médio (últimos 10 episódios)   150.0,  placar 4x2,  epsilon: 0.015
# episódio 190,  retorno -4000.0,  retorno médio (últimos 10 episódios)  -550.0,  placar 0x4,  epsilon: 0.015
# episódio 191,  retorno  2500.0,  retorno médio (últimos 10 episódios)  -650.0,  placar 4x3,  epsilon: 0.015
# episódio 192,  retorno  3500.0,  retorno médio (últimos 10 episódios)   100.0,  placar 4x1,  epsilon: 0.014
# episódio 193,  retorno -4000.0,  retorno médio (últimos 10 episódios)    50.0,  placar 0x4,  epsilon: 0.014
# episódio 194,  retorno  4000.0,  retorno médio (últimos 10 episódios)   200.0,  placar 4x0,  epsilon: 0.014
# episódio 195,  retorno  3000.0,  retorno médio (últimos 10 episódios)   850.0,  placar 4x2,  epsilon: 0.014
# episódio 196,  retorno  3500.0,  retorno médio (últimos 10 episódios)  1150.0,  placar 4x1,  epsilon: 0.013
# episódio 197,  retorno  4000.0,  retorno médio (últimos 10 episódios)  1800.0,  placar 4x0,  epsilon: 0.013
# episódio 198,  retorno   500.0,  retorno médio (últimos 10 episódios)  1600.0,  placar 2x1,  epsilon: 0.013
# episódio 199,  retorno  3500.0,  retorno médio (últimos 10 episódios)  1650.0,  placar 4x1,  epsilon: 0.013
# episódio 200,  retorno     0.0,  retorno médio (últimos 10 episódios)  2050.0,  placar 3x3,  epsilon: 0.012
# episódio 201,  retorno  3000.0,  retorno médio (últimos 10 episódios)  2100.0,  placar 4x2,  epsilon: 0.012
# episódio 202,  retorno  3000.0,  retorno médio (últimos 10 episódios)  2050.0,  placar 4x2,  epsilon: 0.012
# episódio 203,  retorno -3500.0,  retorno médio (últimos 10 episódios)  2100.0,  placar 1x4,  epsilon: 0.012
# episódio 204,  retorno  2500.0,  retorno médio (últimos 10 episódios)  1950.0,  placar 4x3,  epsilon: 0.011
# episódio 205,  retorno -2500.0,  retorno médio (últimos 10 episódios)  1400.0,  placar 3x4,  epsilon: 0.011
# episódio 206,  retorno  3000.0,  retorno médio (últimos 10 episódios)  1350.0,  placar 4x2,  epsilon: 0.011
# episódio 207,  retorno  3500.0,  retorno médio (últimos 10 episódios)  1300.0,  placar 4x1,  epsilon: 0.011
# episódio 208,  retorno   500.0,  retorno médio (últimos 10 episódios)  1300.0,  placar 2x1,  epsilon: 0.010
# episódio 209,  retorno  2500.0,  retorno médio (últimos 10 episódios)  1200.0,  placar 4x3,  epsilon: 0.010
# episódio 210,  retorno  3000.0,  retorno médio (últimos 10 episódios)  1500.0,  placar 4x2,  epsilon: 0.010
# episódio 211,  retorno  2500.0,  retorno médio (últimos 10 episódios)  1450.0,  placar 4x3,  epsilon: 0.010
# episódio 212,  retorno -2500.0,  retorno médio (últimos 10 episódios)   900.0,  placar 3x4,  epsilon: 0.010
# episódio 213,  retorno -3000.0,  retorno médio (últimos 10 episódios)   950.0,  placar 2x4,  epsilon: 0.010
# episódio 214,  retorno  2500.0,  retorno médio (últimos 10 episódios)   950.0,  placar 4x3,  epsilon: 0.010
# episódio 215,  retorno -3000.0,  retorno médio (últimos 10 episódios)   900.0,  placar 2x4,  epsilon: 0.010
# episódio 216,  retorno  2500.0,  retorno médio (últimos 10 episódios)   850.0,  placar 4x3,  epsilon: 0.010
# episódio 217,  retorno     0.0,  retorno médio (últimos 10 episódios)   500.0,  placar 2x2,  epsilon: 0.010
# episódio 218,  retorno  3000.0,  retorno médio (últimos 10 episódios)   750.0,  placar 4x2,  epsilon: 0.010
# episódio 219,  retorno  4000.0,  retorno médio (últimos 10 episódios)   900.0,  placar 4x0,  epsilon: 0.010
# episódio 220,  retorno  4000.0,  retorno médio (últimos 10 episódios)  1000.0,  placar 4x0,  epsilon: 0.010
# episódio 221,  retorno -3000.0,  retorno médio (últimos 10 episódios)   450.0,  placar 2x4,  epsilon: 0.010
# episódio 222,  retorno  3000.0,  retorno médio (últimos 10 episódios)  1000.0,  placar 4x2,  epsilon: 0.010
# episódio 223,  retorno -3000.0,  retorno médio (últimos 10 episódios)  1000.0,  placar 2x4,  epsilon: 0.010
# episódio 224,  retorno  2500.0,  retorno médio (últimos 10 episódios)  1000.0,  placar 4x3,  epsilon: 0.010
# episódio 225,  retorno -2500.0,  retorno médio (últimos 10 episódios)  1050.0,  placar 3x4,  epsilon: 0.010
# episódio 226,  retorno -3000.0,  retorno médio (últimos 10 episódios)   500.0,  placar 2x4,  epsilon: 0.010
# episódio 227,  retorno  2500.0,  retorno médio (últimos 10 episódios)   750.0,  placar 4x3,  epsilon: 0.010
# episódio 228,  retorno -3500.0,  retorno médio (últimos 10 episódios)   100.0,  placar 1x4,  epsilon: 0.010
# episódio 229,  retorno -4000.0,  retorno médio (últimos 10 episódios)  -700.0,  placar 0x4,  epsilon: 0.010
# episódio 230,  retorno -3000.0,  retorno médio (últimos 10 episódios) -1400.0,  placar 2x4,  epsilon: 0.010
# episódio 231,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1350.0,  placar 3x4,  epsilon: 0.010
# episódio 232,  retorno  2500.0,  retorno médio (últimos 10 episódios) -1400.0,  placar 4x3,  epsilon: 0.010
# episódio 233,  retorno -3500.0,  retorno médio (últimos 10 episódios) -1450.0,  placar 1x4,  epsilon: 0.010
# episódio 234,  retorno -2500.0,  retorno médio (últimos 10 episódios) -1950.0,  placar 3x4,  epsilon: 0.010
# episódio 235,  retorno -3500.0,  retorno médio (últimos 10 episódios) -2050.0,  placar 1x4,  epsilon: 0.010
# episódio 236,  retorno  3500.0,  retorno médio (últimos 10 episódios) -1400.0,  placar 4x1,  epsilon: 0.010
# episódio 237,  retorno  4000.0,  retorno médio (últimos 10 episódios) -1250.0,  placar 4x0,  epsilon: 0.010
# episódio 238,  retorno  4000.0,  retorno médio (últimos 10 episódios)  -500.0,  placar 4x0,  epsilon: 0.010
# episódio 239,  retorno  3500.0,  retorno médio (últimos 10 episódios)   250.0,  placar 4x1,  epsilon: 0.010
# episódio 240,  retorno  3000.0,  retorno médio (últimos 10 episódios)   850.0,  placar 4x2,  epsilon: 0.010
# episódio 241,  retorno -3500.0,  retorno médio (últimos 10 episódios)   750.0,  placar 1x4,  epsilon: 0.010
# episódio 242,  retorno -4000.0,  retorno médio (últimos 10 episódios)   100.0,  placar 0x4,  epsilon: 0.010
# episódio 243,  retorno  4000.0,  retorno médio (últimos 10 episódios)   850.0,  placar 4x0,  epsilon: 0.010
# episódio 244,  retorno -4000.0,  retorno médio (últimos 10 episódios)   700.0,  placar 0x4,  epsilon: 0.010
# episódio 245,  retorno  2500.0,  retorno médio (últimos 10 episódios)  1300.0,  placar 4x3,  epsilon: 0.010
# episódio 246,  retorno  3000.0,  retorno médio (últimos 10 episódios)  1250.0,  placar 4x2,  epsilon: 0.010
# episódio 247,  retorno  4000.0,  retorno médio (últimos 10 episódios)  1250.0,  placar 4x0,  epsilon: 0.010
# episódio 248,  retorno  3500.0,  retorno médio (últimos 10 episódios)  1200.0,  placar 4x1,  epsilon: 0.010
# episódio 249,  retorno  2500.0,  retorno médio (últimos 10 episódios)  1100.0,  placar 4x3,  epsilon: 0.010
# episódio 250,  retorno  3000.0,  retorno médio (últimos 10 episódios)  1100.0,  placar 4x2,  epsilon: 0.010

# %% [markdown]
# ## 🏓 Testando nosso Agente Treinado

# %%
roda_partida(env, Q)
